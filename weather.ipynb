# %%
import requests

# %%
response = requests.get("https://wttr.in/Tulcea")

# %%
response.status_code
# Out:
# 200

# %%
print(response.text)
# Out:
# Weather report: Tulcea
#
#        .-.      Light rain
#       (   ).    +8(5) °C
#      (___(__)   ↖ 17 km/h
#       ‘ ‘ ‘ ‘   8 km
#      ‘ ‘ ‘ ‘    0.0 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Mon 26 Jan ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │               Cloudy         │      .-.      Light rain     │               Overcast       │      .-.      Light drizzle  │
# │      .--.     +6(3) °C       │     (   ).    +8(6) °C       │      .--.     +7(4) °C       │     (   ).    +7(4) °C       │
# │   .-(    ).   ↖ 13-27 km/h   │    (___(__)   ↖ 17-28 km/h   │   .-(    ).   ← 14-25 km/h   │    (___(__)   ← 16-28 km/h   │
# ...
